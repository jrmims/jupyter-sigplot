# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "images/Untitled.ipynb_47678e3f3f6c4c708637793992675292.png")
# Out:
# <img src="images/Untitled.ipynb_47678e3f3f6c4c708637793992675292.png"/>

# %%
import os
from jupyter_sigplot.sigplot import SigPlot


plot = SigPlot()
#os.chdir("jimTest")
#os.chdir("..")


plot.overlay_href("http://sigplot.lgsinnovations.com/dat/pulse.tmp")
plot.plot()
#plot.jimPlot()
print(plot.data)
# Out:
# SigPlot()
# []

# %%
#plot.jimPlot()
import IPython
from binascii import a2b_base64
base64Data = plot.data
byteData = a2b_base64(plot.data)
#IPython.display.display(a2b_base64(plot.data))
#plot.jimPlot()

# %%
IPython.display.Image(byteData)

# %%
IPython.display.Image(base64Data)

# %%
IPython.display.display()

# %%
IPython.display.Javascript(plot.plot())
# Out:
# U2lnUGxvdChkb25lPVRydWUsIGhyZWZfb2JqPXt1J2xheWVyVHlwZSc6IHUnMUQnLCB1J2ZpbGVuYW1lJzogdSdwdWxzZS50bXAnfSwgb2xkSHJlZnM9W3t1J2xheWVyVHlwZSc6IHUnMUQnLCDigKY=
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/jmims/jupyter-sigplot/local/lib/python2.7/site-packages/ipython-5.7.0-py2.7.egg/IPython/core/formatters.pyc in __call__(self, obj)
#     336             method = get_real_method(obj, self.print_method)
#     337             if method is not None:
# --> 338                 return method()
#     339             return None
#     340         else:
#
# /home/jmims/jupyter-sigplot/local/lib/python2.7/site-packages/ipython-5.7.0-py2.7.egg/IPython/core/display.pyc in _repr_javascript_(self)
#     891         for l in self.lib:
#     892             r += lib_t1 % l
# --> 893         r += self.data
#     894         r += lib_t2*len(self.lib)
#     895         return r
#
# ...

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
#%matplotlib inline
# %matplotlib notebook


x = np.linspace(0, 3*np.pi, 500)
plt.plot(x, np.sin(x**2))
plt.title('A simple chirp')
plt.show()
